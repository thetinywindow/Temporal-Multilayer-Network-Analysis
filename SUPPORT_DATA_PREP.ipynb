# %%
import pandas as pd
import numpy as np
import os
import codecs

# %%
#pip install codec

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
# /opt/anaconda/envs/Python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   if __name__ == '__main__':

# %% [markdown]
# ### Check Existing Input Files

# %%
#set file-path to 'DATA/'
file_path = 'DATA/'

#check for # of files and filenames
filenames = os.listdir(file_path)
len(filenames), filenames
# Out:
# (10,
#  ['savedrecs-5.txt',
#   'savedrecs-9.txt',
#   'savedrecs-10.txt',
#   'savedrecs-7.txt',
#   'savedrecs-3.txt',
#   'savedrecs.txt',
#   'savedrecs-6.txt',
#   'savedrecs-2.txt',
#   'savedrecs-8.txt',
#   'savedrecs-4.txt'])

# %% [markdown]
# ### Generate full DataFrame

# %%
#generate 'empty' dataframe -> to only filter column names
filename =  file_path + filenames[0]
doc = codecs.open(filename,'rU','UTF-8')
df_col = pd.read_csv(doc, sep='\t')

#reset variables
res = []
df_add = []

#set base dataframe only including column names
df_base = pd.DataFrame(columns=df_col.columns)


for file in filenames:
    path = file_path+file
    doc = codecs.open(path,'rU','UTF-8')
    
    df_add = pd.read_csv(doc, sep='\t')
    #res = df_base.append(df_add)
    df_base = df_base.append(df_add)

df = df_base
df.shape
# Out:
# (4722, 67)

# %%
df.head()
# Out:
#                                                                  PT   AU   BA   BE                                                                                                     GP   AF   BF                                                                                                                                       CA                                                     TI   SO  SE       BS       LA   DT   CT   CY   CL   SP                                                    HO                                                                                                                                                  DE  \
# ...

# %%
#1999 - 2005 - 647
#2006 - 2012 - 964
#2013 - 2019 - 1567

# %%
#1985 - 2003 - 18 - 1214
#2004 - 2012 - 9  - 1181
#2013 - 2019 - 7  - 1567

# %%
#transfer into csv
#df.to_csv(r'combined_WoS', index = False)

# %%
#outout
df_year = df[df['PD']>=1985]
#df_year = df_year[df_year['PD']<=2012]
df_year.shape #= df_year[['CA','HO']]
# Out:
# (3994, 67)

# %%
df_year.to_csv(r'FP_check2.csv', index = True)

# %%
#df_year.head(10)

# %%
#ID; Abstract- ID; Title - CA;  keywords; 
#1999 - 2005
#2006 - 2012
#2013 - 2019

#df = df[['ID','CA','HO','PD']]
#df = df.reset_index().drop('index', axis=1)

#df = df[df['PD']<=2005]
#df = df[df['PD']>=1999]
#df = df[['ID','CA','HO']]
#df = df.rename(columns={"ID": "ABSTRACT", "CA": "TITLE","HO":"KEYWORDS"})

#df.to_csv(r'cluster3_1999-2005.csv', index = True)
